# %% [markdown]
# # Graphs

# %%
#remove the warnings
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.Series(np.random.randn(1000),index=pd.date_range("1/1/2019",periods =1000))
data= data.cumsum()
data.plot()
# Out:
# <AxesSubplot:>

# %%
dataframe = pd.DataFrame(np.random.randn(1000,4),index=data.index,columns=list("ABCD"))
dataframe= dataframe.cumsum()
#plt.figure()
dataframe.plot()
# Out:
# <AxesSubplot:>

# %%
dataframe1= pd.DataFrame(np.random.randn(1000,2),columns=["B","C"]).cumsum()
dataframe1["A"]= pd.Series(list(range(len(dataframe))))
dataframe1.plot(x="A",y="B")
# Out:
# <AxesSubplot:xlabel='A'>

# %%
dataframe.iloc[5].plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
#axhline gives the horizontal line
dataframe.iloc[5].plot.bar()
plt.axhline(0,color="r")

# %%
dataframe2 = pd.DataFrame(np.random.randn(10,4),columns=["a","b","c","d"])
dataframe2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
dataframe2 = pd.DataFrame(np.random.rand(10,4),columns=["a","b","c","d"])
dataframe2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
dataframe2.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
dataframe2.plot.barh(stacked =True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Histrogram

# %%
dataframe4 = pd.DataFrame({"a":np.random.randn(1000) + 1,"b": np.random.randn(1000),
                          "c":np.random.randn(1000) -1},columns=["a",'b','c'])
dataframe4.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
dataframe4 = pd.DataFrame({"a":np.random.randn(1000) + 1,"b": np.random.randn(1000),
                          "c":np.random.randn(1000) -1},columns=["a",'b','c'])
dataframe4.plot.hist(alpha= 0.5)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
dataframe4.plot.hist(stacked=True,bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
dataframe4["a"].plot.hist(orientation= "horizontal",cumulative = True)
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
dataframe4.diff().hist()
# Out:
# array([[<AxesSubplot:title={'center':'a'}>,
#         <AxesSubplot:title={'center':'b'}>],
#        [<AxesSubplot:title={'center':'c'}>, <AxesSubplot:>]], dtype=object)

# %%
dataframe4["a"].diff().hist()
# Out:
# <AxesSubplot:>

# %%
dataframe4.diff().hist(color='r',alpha=0.5,bins=20)
# Out:
# array([[<AxesSubplot:title={'center':'a'}>,
#         <AxesSubplot:title={'center':'b'}>],
#        [<AxesSubplot:title={'center':'c'}>, <AxesSubplot:>]], dtype=object)

# %%
data = pd.Series(np.random.randn(1000))
data.hist(by=np.random.randint(0,4,1000),figsize=(6,4))
# Out:
# array([[<AxesSubplot:title={'center':'0'}>,
#         <AxesSubplot:title={'center':'1'}>],
#        [<AxesSubplot:title={'center':'2'}>,
#         <AxesSubplot:title={'center':'3'}>]], dtype=object)

# %% [markdown]
# # Boxplot

# %%
data=pd.DataFrame(np.random.rand(10,5),columns=["A","B","C","D","E"])
data.plot.box()
# Out:
# <AxesSubplot:>

# %%
color = {"boxes":"DarkGreen","whiskers":"DarkOrange","medians":"DarkBlue","caps":"Gray"}
data.plot.box(color=color,sym="r+")
# Out:
# <AxesSubplot:>

# %%
data.plot.box(vert=False,positions=[1,4,5,6,8])
# Out:
# <AxesSubplot:>

# %% [markdown]
# # grouped boxplot

# %%
data1 = pd.DataFrame(np.random.rand(10,2),columns=["col1","col2"])
data1["x"]=pd.Series(["A","A","A","A","A","B","B","B","B","B"])
data1.boxplot(by = "x")
# Out:
# array([<AxesSubplot:title={'center':'col1'}, xlabel='[x]'>,
#        <AxesSubplot:title={'center':'col2'}, xlabel='[x]'>], dtype=object)

# %%
data=pd.DataFrame(np.random.rand(10,4),columns=["a","b","c","d"])
data.plot.area()
# Out:
# <AxesSubplot:>

# %%
data.plot.area(stacked=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Scatterplot

# %%
data = pd.DataFrame(np.random.rand(50,4),columns=["a","b","c","d"])
data.plot.scatter(x="a",y="b")
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
ax = data.plot.scatter(x="a",y="b",color= 'DarkBlue',label ="Group1")
data.plot.scatter(x="c",y="d",color= 'DarkGreen',label ="Group2",ax=ax)
# Out:
# <AxesSubplot:xlabel='c', ylabel='d'>

# %%
data.plot.scatter(x="a",y="b",c= 'c',s= 50)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %% [markdown]
# # Hexagonal Bin plot

# %%
data = pd.DataFrame(np.random.randn(1000,2),columns=["a","b"])
data["b"]=data["b"] + np.arange(1000)
data.plot.hexbin(x="a",y="b",gridsize=25)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %% [markdown]
# # PiePlot

# %%
series = pd.Series(5*np.random.rand(4),index=["a","b","c","d"],name = "series")
series.plot.pie()
# Out:
# <AxesSubplot:ylabel='series'>

# %%
data = pd.DataFrame(3*np.random.rand(4,2),index= ["a","b","c","d"],columns=["x","y"])
data.plot.pie(subplots = True,figsize=(8,6))
# Out:
# array([<AxesSubplot:ylabel='x'>, <AxesSubplot:ylabel='y'>], dtype=object)

# %%
series.plot.pie(labels=["AA","BB","CC","DD"],
               colors= ["r","g","b","c"],
                        autopct= "%.2f",fontsize =20,figsize=(20,6))
# Out:
# <AxesSubplot:ylabel='series'>

# %%
series = pd.Series([.4]*4,index= ["a","b","c","d"],name = "series")
series.plot.pie(figsize=(10,6))
# Out:
# <AxesSubplot:ylabel='series'>

# %% [markdown]
# # Table

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
fig,ax=plt.subplots(1,1,figsize=(10,6))
data = pd.DataFrame(np.random.rand(5,3),columns=["a","b","c"])

ax.xaxis.tick_top()
data.plot(table=True,ax=ax)
# Out:
# <AxesSubplot:>

# %%
from pandas.plotting import table
fig,ax=plt.subplots(1,1)
table(ax,np.round(data.describe(),2),
     loc= "upper right",colWidths =[0.2,0.2,0.2])
data.plot(ax=ax,ylim =(0,2),legend =None)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # exercise on loan data

# %%
import pandas as pd
import numpy as np
import os
# displays current working directory
os.getcwd()
# Out:
# 'C:\\Users\\rproddatur\\Desktop\\jig saw'

# %%
#changes the directory
os.chdir("C:\\Users\\rproddatur\\Documents\\Delloit_training(10-14-2021)")

# %%
loan=pd.read_csv("train.csv")
print(loan.head(50))
print(loan.tail(10))
# Out:
#      Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0   LP001002    Male      No          0      Graduate            No
# 1   LP001003    Male     Yes          1      Graduate            No
# 2   LP001005    Male     Yes          0      Graduate           Yes
# 3   LP001006    Male     Yes          0  Not Graduate            No
# 4   LP001008    Male      No          0      Graduate            No
# 5   LP001011    Male     Yes          2      Graduate           Yes
# 6   LP001013    Male     Yes          0  Not Graduate            No
# 7   LP001014    Male     Yes         3+      Graduate            No
# 8   LP001018    Male     Yes          2      Graduate            No
# 9   LP001020    Male     Yes          1      Graduate            No
# 10  LP001024    Male     Yes          2      Graduate            No
# 11  LP001027    Male     Yes          2      Graduate           NaN
# 12  LP001028    Male     Yes          2      Graduate            No
# ...

# %%
loan[:50]
# Out:
#      Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0   LP001002    Male      No          0      Graduate            No
# 1   LP001003    Male     Yes          1      Graduate            No
# 2   LP001005    Male     Yes          0      Graduate           Yes
# 3   LP001006    Male     Yes          0  Not Graduate            No
# 4   LP001008    Male      No          0      Graduate            No
# 5   LP001011    Male     Yes          2      Graduate           Yes
# 6   LP001013    Male     Yes          0  Not Graduate            No
# 7   LP001014    Male     Yes         3+      Graduate            No
# 8   LP001018    Male     Yes          2      Graduate            No
# 9   LP001020    Male     Yes          1      Graduate            No
# 10  LP001024    Male     Yes          2      Graduate            No
# 11  LP001027    Male     Yes          2      Graduate           NaN
# 12  LP001028    Male     Yes          2      Graduate            No
# ...

# %%
loan.shape
# Out:
# (614, 13)

# %%
loan.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 609    False
# 610    False
# 611    False
# 612    False
# 613    False
# Length: 614, dtype: bool

# %%
loan.duplicated().sum()
# Out:
# 0

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
loan
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
# shows the null values
loan.isnull()
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      False   False    False       False      False          False
# 1      False   False    False       False      False          False
# 2      False   False    False       False      False          False
# 3      False   False    False       False      False          False
# 4      False   False    False       False      False          False
# ..       ...     ...      ...         ...        ...            ...
# 609    False   False    False       False      False          False
# 610    False   False    False       False      False          False
# 611    False   False    False       False      False          False
# 612    False   False    False       False      False          False
# 613    False   False    False       False      False          False
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              False              False        True             False
# ...

# %%
loan.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
#shows the null values
loan.isna()
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      False   False    False       False      False          False
# 1      False   False    False       False      False          False
# 2      False   False    False       False      False          False
# 3      False   False    False       False      False          False
# 4      False   False    False       False      False          False
# ..       ...     ...      ...         ...        ...            ...
# 609    False   False    False       False      False          False
# 610    False   False    False       False      False          False
# 611    False   False    False       False      False          False
# 612    False   False    False       False      False          False
# 613    False   False    False       False      False          False
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              False              False        True             False
# ...

# %%
loan.isna().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
#shows null values in desecnding order
loan.isnull().sum().sort_values(ascending=False)
# Out:
# Credit_History       50
# Self_Employed        32
# LoanAmount           22
# Dependents           15
# Loan_Amount_Term     14
# Gender               13
# Married               3
# Loan_ID               0
# Education             0
# ApplicantIncome       0
# CoapplicantIncome     0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
#shows the column names
list(loan.columns)
# Out:
# ['Loan_ID',
#  'Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'ApplicantIncome',
#  'CoapplicantIncome',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History',
#  'Property_Area',
#  'Loan_Status']

# %%
# slice the column
Loan_id=loan.Loan_ID

# %%
Loan_id
# Out:
# 0      LP001002
# 1      LP001003
# 2      LP001005
# 3      LP001006
# 4      LP001008
#          ...
# 609    LP002978
# 610    LP002979
# 611    LP002983
# 612    LP002984
# 613    LP002990
# Name: Loan_ID, Length: 614, dtype: object

# %%
loan.drop(["Loan_ID"],axis=1,inplace=True)

# %%
loan.shape
# Out:
# (614, 12)

# %%
list(loan.columns)
# Out:
# ['Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'ApplicantIncome',
#  'CoapplicantIncome',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History',
#  'Property_Area',
#  'Loan_Status']

# %%
loan['Gender'].value_counts()
# Out:
# Male      489
# Female    112
# Name: Gender, dtype: int64

# %%
#replcae the nan value with male
loan["Gender"]=loan["Gender"].astype('str').transform(lambda x: x.replace('nan','Male'))

# %%
#sometimes it show error if we dont give astype
loan["Gender"]=loan["Gender"].transform(lambda x: x.replace('nan','Male'))

# %%
loan.isnull().sum()
# Out:
# Gender                0
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
loan.Gender.value_counts()
# Out:
# Male      502
# Female    112
# Name: Gender, dtype: int64

# %%
loan.Married.value_counts()
# Out:
# Yes    398
# No     213
# Name: Married, dtype: int64

# %%
loan["Married"]=loan["Married"].astype('str').transform(lambda x: x.replace('nan','Yes'))

# %%
loan.isnull().sum()
# Out:
# Gender                0
# Married               0
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
loan.Dependents.value_counts()
# Out:
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: Dependents, dtype: int64

# %%
loan.Dependents=loan.Dependents.replace('3+' ,'3')

# %%
loan.Dependents.value_counts()
# Out:
# 0    345
# 1    102
# 2    101
# 3     51
# Name: Dependents, dtype: int64

# %%
loan.Dependents=loan.Dependents.astype('str').transform(lambda x: x.replace('nan','0'))

# %%
loan.isnull().sum()
# Out:
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
loan.Self_Employed.value_counts()
# Out:
# No     500
# Yes     82
# Name: Self_Employed, dtype: int64

# %%
loan.Self_Employed=loan.Self_Employed.astype('str').transform(lambda x: x.replace('nan','Yes'))

# %%
loan.Self_Employed.value_counts()
# Out:
# No     500
# Yes    114
# Name: Self_Employed, dtype: int64

# %%
loan.LoanAmount.mean()
# Out:
# 146.41216216216216

# %%
loan.LoanAmount.median()
# Out:
# 128.0

# %%
loan.LoanAmount.mode()
# Out:
# 0    120.0
# dtype: float64

# %%
loan.LoanAmount.min()
# Out:
# 9.0

# %%
loan.LoanAmount.max()
# Out:
# 700.0

# %%
loan.LoanAmount.std()
# Out:
# 85.58732523570545

# %%
loan.LoanAmount=loan.LoanAmount.fillna(146.41)

# %%
loan.isnull().sum()
# Out:
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
loan.Loan_Amount_Term.value_counts()
# Out:
# 360.0    512
# 180.0     44
# 480.0     15
# 300.0     13
# 84.0       4
# 240.0      4
# 120.0      3
# 36.0       2
# 60.0       2
# 12.0       1
# Name: Loan_Amount_Term, dtype: int64

# %%
loan.Loan_Amount_Term = loan.Loan_Amount_Term.astype('str').transform(lambda x: x.replace('nan','360.0'))

# %%
loan.Credit_History.value_counts()
# Out:
# 1.0    475
# 0.0     89
# Name: Credit_History, dtype: int64

# %%
loan.Credit_History = loan.Credit_History.astype('str').transform(lambda x: x.replace('nan','1.0'))

# %%
loan.isnull().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
# remove all the null values in the table

# %%
import matplotlib.pyplot as plt
loan.Gender.value_counts().sort_values(ascending = False).plot.bar()
plt.savefig("Gender data") # saves the garph in the specifeid diectory loaction

# %%
#shows the version of the package
import matplotlib
matplotlib.__version__
# Out:
# '3.3.4'

# %%
import pandas
pandas.__version__
# Out:
# '1.2.4'

# %%
loan.groupby(["Gender","Loan_Status"])["Gender"].count().sort_values(ascending=False).plot.bar()
# Out:
# <AxesSubplot:xlabel='Gender,Loan_Status'>

# %%
# plot the garph for all the records

# %%
loan.isnull().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
loan.groupby(["Gender","Married"])["Married"].count().sort_values(ascending=False).plot.bar()
# Out:
# <AxesSubplot:xlabel='Gender,Married'>

# %% [markdown]
# # Exercise on iris dataset

# %%
import pandas as pd
import numpy as np
import os
os.chdir("C:\\Users\\rproddatur\\Documents\\deloitte_training(18-10-2021)\\deloitte_training(18-10-2021)\\iris")

# %%
# loads the csv file into data
data=pd.read_csv("Iris.csv")
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
list(data.columns)
# Out:
# ['Id',
#  'SepalLengthCm',
#  'SepalWidthCm',
#  'PetalLengthCm',
#  'PetalWidthCm',
#  'Species']

# %%
data.Species.value_counts()
# Out:
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        50
# Name: Species, dtype: int64

# %% [markdown]
# # display image

# %%
#displays the image
from IPython.display import Image

# %%
Image(filename="setosa.jpg",width=250,height=50)

# %%
Image(filename="versicolor.jpg",width=250,height=50)

# %%
Image(filename="Virginica.jpg",width=250,height=50)

# %%
data.shape
# Out:
# (150, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
# Gives the quartile values like count,min,max,std,mean,25%,50%,75%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
# gives the count of null values
data.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# # Heatmap

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# shows the maps in colors for easy identification

# %%
# very high relations are shown in one different color 
# negative relations are shown in one different color
# this is represented only for numerical not for categorical
colormap = plt.cm.viridis
plt.figure(figsize=(12,12))
plt.title("correlation",y = 1.05,size = 15)
sns.heatmap(data.corr(),linewidth=0.1,vmax=1.0,square=True,cmap=colormap,linecolor="white",annot = True)
# Out:
# <AxesSubplot:title={'center':'correlation'}>

# %%
# plots the bar graph
plt.figure(figsize=(10,10))
data.SepalLengthCm.value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
# Draw bar plot for remaining features and compare

# %%
# plots the box plot
sns.boxplot(data=data,y="SepalLengthCm",x="Species")
# Out:
# <AxesSubplot:xlabel='Species', ylabel='SepalLengthCm'>

# %%
sns.boxplot(data=data,y="Species",x="SepalLengthCm")
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='Species'>

# %%
#if median value is in middle then it is normal
#if median value is left then it is right skewed
#if median value is right then it is left skewed

# %%
#shows the shape of distribution
sns.distplot(data.SepalLengthCm)
# Out:
# C:\Users\rproddatur\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='Density'>

# %%
sns.distplot(data.SepalWidthCm)
# Out:
# C:\Users\rproddatur\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SepalWidthCm', ylabel='Density'>

# %%
sns.distplot(data.PetalLengthCm)
# Out:
# C:\Users\rproddatur\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='Density'>

# %%
sns.distplot(data.PetalWidthCm)
# Out:
# C:\Users\rproddatur\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='PetalWidthCm', ylabel='Density'>

# %% [markdown]
# # Plotly pakage

# %%
# we plot graphs using plotly

# %%
import pandas as pd
import numpy as np
import scipy as sp
# pip install chart-studio
# from chart_studio.plotly import iplot
from chart_studio.plotly import iplot

# %%
import plotly.graph_objs as go

# %%
# pip install cufflinks
import cufflinks as cf

# %%
from Ipython.core.interactiveshell import interactiveShell
InteractiveShell.as_node_interactivity - "all"

# %%
# set the column size to 100
pd.option.display.max_columns = 100

# %%
import os
os.chdir("...")

# %%
data=pd.read_csv("50-Statups.csv")

# %%
from plotly.offline import iplot,init_notebook_mode
init_notebook_mode(connected = True)
cf.go_offline(connected = True)
cf.set_config_file(world_readable = True, theme = "pearl")

# %%
data.plot()

# %%
# plot with the help of model plotly
# if we move cursor we can see the point values
data.iplot(mode="lines+markers",opacity=0.8,size=8,symbol=3,text="State",xTitle="no of record",yTitle="Amount spend",title="Statup company")

# %%
# plot for profits
data.iplot(x="Profit",mode="lines+markers",opacity=0.8,size=8,symbol=3,text="State",xTitle="Profit",yTitle="Amount spend",title="Statup company")

# %%
# plot for only first 20 points
# we can use for loops also
data[:20].iplot(x="Profit",mode="lines+markers",opacity=0.8,size=8,symbol=3,text="State",xTitle="Profit",yTitle="Amount spend",title="Statup company")

# %%
# histogram 
# if we double click it gives the plot of particulat data point 
data.iplot(kind="hist",x="Profit",mode="lines+markers",opacity=0.8,size=8,symbol=3,text="State",xTitle="Profit",yTitle="Amount spend",title="Statup company")

# %%
# 
data.iplot(kind="hist",x="Profit",mode="lines+markers",opacity=0.8,size=8,symbol=3,text="State",xTitle="Profit",yTitle="Amount spend",title="Statup company")

# %%
data.iplot(kind="hist",linecolor="black",bins=24s,bargap=0.1,barmode=,x="Profit",mode="lines+markers",opacity=0.8,size=8,symbol=3,text="State",xTitle="Profit",yTitle="Amount spend",title="Statup company")

# %%
# bar plot 
# if we move cursor we can see values and can view only paticulatar data points
data.iplot(kind="bar")

# %%
# shows the box plot for state(categorical) and profit (numerical)
data[["state","profit"]].pivot(columns="state" , values = "Profit").iplot(kind="box")

# %%
# if we spend both numerical it will give multiple box plots whic is not undestandable
data[["R&D Spend","profit"]].pivot(columns="R&D Spend" , values = "Profit").iplot(kind="box")

# %%
# scatterplot
import plotly.express as px
fig=px.scatter(data,x="R&D Spend",y="Marketing Spend",color="State",size="Profit",hover_data="profit",symbol="State")

# %%
# 
fig=px.scatter(data,x="Marketing Spend",y="profit",color="State",size="Profit",hover_data="profit",symbol="State")

# %%
fig=px.scateplot(data,x="Administartion",y="profit")
fig.show()

# %%
# if the data points are upwards from left to right then it is used further
# if the points are scattered it is having no relataion
data.iplot(x="profit",mode="markers",text="State")

# %%
# it gives the complete pair plot
# it shows the realation between all the data points
# it shows the histogram also for each combination 
import plotly.figure_factory as ff
figure = ff.create_scatterplotmatrix(data[["R&D Spend","Administration","Marketing Spend","Profit","State"]],height = 1000,width=4000,text = data["state"],diag="Historam",index="State")
iplot(figure)

# %%
# pieplot
fig=px.pie(data,values="R&D Spend",names="State")
fig.show()

# %%
# heatmap
colors=["Greys","YIGnBu","Greens","yIOrRd"]
corrs=data.corr()
figure=ff.create_annotated_heatmap(z=corr.values,x=list(corr.columns),y=list(corr.index),colorscale="Earth",annotation_text=corrs.round(2),values,showscale=True,reversescale=True)
figure.layout.margin=dict(1==200,t==200)
figure.layout.height=800
figure.layout.width=1000
iplot(figure)

# %% [markdown]
# # Creating a pivot tables

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
os.chdir("C:\\Users\\rproddatur\\Documents\\deloitte_training(18-10-2021)\\deloitte_training(18-10-2021)\\lending_club")

# %%
# the low memory will not dispaly complete design
data=pd.read_csv("loan.csv",low_memory= False)
data.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# 3   13.49%       339.31     C        C1  ...                NaN
# 4   12.69%        67.79     B        B5  ...                NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# ...

# %%
data.shape
# Out:
# (39717, 111)

# %%
list(data.columns)
# Out:
# ['id',
#  'member_id',
#  'loan_amnt',
#  'funded_amnt',
#  'funded_amnt_inv',
#  'term',
#  'int_rate',
#  'installment',
#  'grade',
#  'sub_grade',
#  'emp_title',
#  'emp_length',
#  'home_ownership',
#  'annual_inc',
#  'verification_status',
#  'issue_d',
#  'loan_status',
#  'pymnt_plan',
#  'url',
#  'desc',
#  'purpose',
#  'title',
#  'zip_code',
#  'addr_state',
#  'dti',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'initial_list_status',
#  'out_prncp',
#  'out_prncp_inv',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'recoveries',
#  'collection_recovery_fee',
#  'last_pymnt_d',
#  'last_pymnt_amnt',
#  'next_pymnt_d',
#  'last_credit_pull_d',
#  'collections_12_mths_ex_med',
#  'mths_since_last_major_derog',
#  'policy_code',
#  'application_type',
# ...

# %%
data.emp_title.value_counts()
# Out:
# US Army                        134
# Bank of America                109
# IBM                             66
# AT&T                            59
# Kaiser Permanente               56
#                               ...
# BNSF Railroad                    1
# MacDonald's                      1
# AMG Medical                      1
# Western New York Law Center      1
# Sasaki Associates  Inc.          1
# Name: emp_title, Length: 28820, dtype: int64

# %%
#gives the sum of missing points
data.emp_title.isnull().sum()
# Out:
# 2459

# %%
data.drop(["id","member_id","url","desc","zip_code","title","emp_title"],axis=1,inplace=True)

# %%
# the pivot table is uded to summarize data to organized group
# how to group data using index in pivot table
table = pd.pivot_table(data=data,index=["grade"])
table
# Out:
#        acc_now_delinq    annual_inc  chargeoff_within_12_mths  \
# grade
# A                   0  66648.847979                       0.0
# B                   0  67639.958014                       0.0
# C                   0  67939.195952                       0.0
# D                   0  68524.874605                       0.0
# E                   0  77989.406921                       0.0
# F                   0  84602.272059                       0.0
# G                   0  94386.473133                       0.0
#
#        collection_recovery_fee  collections_12_mths_ex_med  delinq_2yrs  \
# grade
# A                     3.023844                         0.0     0.044621
# B                     6.692019                         0.0     0.115225
# C                    15.563399                         0.0     0.186219
# D                    18.677531                         0.0     0.246279
# E                    28.453310                         0.0     0.241379
# ...

# %%
# how to run pivot table with multiple index
table=pd.pivot_table(data,index=["grade","home_ownership"])

# %%
# we can give different aggregate functions for different features
table=pd.pivot_table(data,index=["grade","home_ownership"],aggfunc={'loan_amnt':np.mean,'loan_status':np.sum})
table
# Out:
#                          loan_amnt  \
# grade home_ownership
# A     MORTGAGE         9171.111757
#       NONE            10000.000000
#       OTHER            7019.791667
#       OWN              8032.641292
#       RENT             8061.830025
# B     MORTGAGE        12743.573203
#       NONE             3400.000000
#       OTHER           11514.062500
#       OWN             10844.327957
#       RENT             9704.069368
# C     MORTGAGE        13069.446140
#       OTHER           10875.000000
#       OWN              9631.574539
#       RENT             9592.015209
# D     MORTGAGE        14382.851942
#       OTHER           11467.647059
#       OWN             11233.994709
#       RENT            10901.235975
# E     MORTGAGE        18604.631829
#       OTHER           12728.571429
#       OWN             14522.081218
#       RENT            13520.218182
# F     MORTGAGE        21141.242661
#       OTHER           25000.000000
#       OWN             15130.303030
# ...

# %%
# gives error
table=pd.pivot_table(data,index=["grade","home_ownership"],aggfunc={'loan_amnt':np.mean(),'loan_status':np.sum()})
table
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-8db9ffa6ffca> in <module>
#       1 # gives error
# ----> 2 table=pd.pivot_table(data,index=["grade","home_ownership"],aggfunc={'loan_amnt':np.mean(),'loan_status':np.sum()})
#       3 table
#
# <__array_function__ internals> in mean(*args, **kwargs)
#
# TypeError: _mean_dispatcher() missing 1 required positional argument: 'a'

# %%
#gives the error
table=pd.pivot_table(data,index=["grade","home_ownership"],aggfunc={'loan_amnt':np.mean,'loan_status':np.mode})
table
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-f202352272cc> in <module>
#       1 #gives the error
# ----> 2 table=pd.pivot_table(data,index=["grade","home_ownership"],aggfunc={'loan_amnt':np.mean,'loan_status':np.mode})
#       3 table
#
# ~\Anaconda3\lib\site-packages\numpy\__init__.py in __getattr__(attr)
#     301                 return Tester
#     302
# --> 303             raise AttributeError("module {!r} has no attribute "
#     304                                  "{!r}".format(__name__, attr))
#     305
#
# AttributeError: module 'numpy' has no attribute 'mode'

# %%
# bar plot for the pivot table
table.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='grade,home_ownership'>

# %% [markdown]
# # contingency table or cross tabulation

# %%
cros_tab=pd.crosstab(data["grade"],data["home_ownership"],margins=False)
cros_tab
# Out:
# home_ownership  MORTGAGE  NONE  OTHER  OWN  RENT
# grade
# A                   5163     1     24  867  4030
# B                   5232     2     32  930  5824
# C                   3277     0     16  597  4208
# D                   2060     0     17  378  2852
# E                   1263     0      7  197  1375
# F                    511     0      2   66   470
# G                    153     0      0   23   140

# %% [markdown]
# # Exercise on loan dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
os.chdir("C:\\Users\\rproddatur\\Documents\\deloitte_training(18-10-2021)\\deloitte_training(18-10-2021)\\lending_club")

# %%
data = pd.read_csv("loan.csv",low_memory = False)
data.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# 3   13.49%       339.31     C        C1  ...                NaN
# 4   12.69%        67.79     B        B5  ...                NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# ...

# %%
data=data.rename(columns={"loan_amnt":"loan_amount","funded_amnt":"funded_amount","funded_amnt_inv":"investor_funds",
                     "int_rate":"intrest_rate","annual_inc":"annual_income"})

# %%
data
# Out:
#             id  member_id  loan_amount  funded_amount  investor_funds  \
# 0      1077501    1296599         5000           5000          4975.0
# 1      1077430    1314167         2500           2500          2500.0
# 2      1077175    1313524         2400           2400          2400.0
# 3      1076863    1277178        10000          10000         10000.0
# 4      1075358    1311748         3000           3000          3000.0
# ...        ...        ...          ...            ...             ...
# 39712    92187      92174         2500           2500          1075.0
# 39713    90665      90607         8500           8500           875.0
# 39714    90395      90390         5000           5000          1325.0
# 39715    90376      89243         5000           5000           650.0
# 39716    87023      86999         7500           7500           800.0
#
#              term intrest_rate  installment grade sub_grade  ...  \
# ...

# %%
data.drop(["id","member_id","emp_title","url","desc","zip_code","title"],axis=1,inplace=True)

# %% [markdown]
# # distribution

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from plotly import tools
import chart_studio.plotly as py
import plotly.figure_factory as ff
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
init_notebook_mode(connected= True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-45-b0b5da669852> in <module>
# ----> 1 from plotly import tools
#       2 import chart_studio.plotly as py
#       3 import plotly.figure_factory as ff
#       4 import plotly.graph_objs as go
#       5 from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
#
# ModuleNotFoundError: No module named 'plotly'

# %%
loan_amount=data["loan_amount"].values

# %%
loan_amount
# Out:
# array([5000, 2500, 2400, ..., 5000, 5000, 7500], dtype=int64)

# %%
fig,ax  = plt.subplots(1,3,figsize=(16,5))

loan_amount = data["loan_amount"].values
funded_amount = data["funded_amount"].values
investor_funds = data["investor_funds"].values

sns.distplot(loan_amount, ax = ax[0],color = '#F7522F')#000000 to FFFFFF
ax[0].set_title("Loan Applied by the Borrower",fontsize = 14)

sns.distplot(funded_amount, ax = ax[1],color = '#2F8FF7')#000000 to FFFFFF
ax[1].set_title("Amount Funded   by the Lender",fontsize = 14)

sns.distplot(investor_funds, ax = ax[2],color = '#2EAD46')#000000 to FFFFFF
ax[2].set_title("Total commited bby investors",fontsize = 14)
# Out:
# Text(0.5, 1.0, 'Total commited bby investors')

# %%
# average loan_amount issued in which year
data.issue_d.value_counts()
# Out:
# Dec-11    2260
# Nov-11    2223
# Oct-11    2114
# Sep-11    2063
# Aug-11    1928
# Jul-11    1870
# Jun-11    1827
# May-11    1689
# Apr-11    1562
# Mar-11    1443
# Jan-11    1380
# Feb-11    1297
# Dec-10    1267
# Oct-10    1132
# Nov-10    1121
# Jul-10    1119
# Sep-10    1086
# Aug-10    1078
# Jun-10    1029
# May-10     920
# Apr-10     827
# Mar-10     737
# Feb-10     627
# Nov-09     602
# Dec-09     598
# Jan-10     589
# Oct-09     545
# Sep-09     449
# Aug-09     408
# Jul-09     374
# Jun-09     356
# May-09     319
# Apr-09     290
# Mar-09     276
# Feb-09     260
# Jan-09     239
# Mar-08     236
# Dec-08     223
# Nov-08     184
# Feb-08     174
# Jan-08     171
# Apr-08     155
# Oct-08      96
# Dec-07      85
# Jul-08      83
# Aug-08      71
# May-08      71
# Jun-08      66
# Oct-07      47
# Nov-07      37
# Aug-07      33
# Sep-08      32
# Jul-07      30
# Sep-07      18
# Jun-07       1
# Name: issue_d, dtype: int64

# %%
data.issue_d.head()
# Out:
# 0    Dec-11
# 1    Dec-11
# 2    Dec-11
# 3    Dec-11
# 4    Dec-11
# Name: issue_d, dtype: object

# %%
import time
import datetime

# %%
data_series=pd.to_datetime(data.issue_d.str.upper(),format='%b-%y',yearfirst= False)

# %%
data["year"]=data_series.dt.year

# %%
data.year.head(10)
# Out:
# 0    2011
# 1    2011
# 2    2011
# 3    2011
# 4    2011
# 5    2011
# 6    2011
# 7    2011
# 8    2011
# 9    2011
# Name: year, dtype: int64

# %%
plt.figure(figsize = (12,8))
sns.barplot('year','loan_amount',data= data,palette = 'tab10')
plt.title('issuance of loan', fontsize = 16)
plt.xlabel('year',fontsize = 16)
plt.ylabel('Average loan amount issued', fontsize = 16)
# Out:
# Text(0, 0.5, 'Average loan amount issued')

# %%
data.loan_status.value_counts()
# Out:
# Fully Paid     32950
# Charged Off     5627
# Current         1140
# Name: loan_status, dtype: int64

# %%
# shows the whether the loan is good loan or bad loan
bad_loan = ["Charged Off"]

data['loan_condition'] = np.nan

def loan_condition(status):
    if status in bad_loan:
        return 'Bad_Loan'
    else:
        return 'Good_Loan'
data['loan_condition']= data['loan_status'].apply(loan_condition)
data['loan_condition']
# Out:
# 0        Good_Loan
# 1         Bad_Loan
# 2        Good_Loan
# 3        Good_Loan
# 4        Good_Loan
#            ...
# 39712    Good_Loan
# 39713    Good_Loan
# 39714    Good_Loan
# 39715    Good_Loan
# 39716    Good_Loan
# Name: loan_condition, Length: 39717, dtype: object

# %%
# bar graph for good loans and bad laons 
f , ax = plt.subplots(1,2,figsize = (16,8))
colors = ["#3791D7","#D72626"]
labels = 'Goodloans','Badloans'

plt.suptitle("Information on loan conditions",fontsize = 16)
data["loan_condition"].value_counts().plot.pie(explode = [0,0.25],autopct= '%1.2f%%',ax = ax[0],
                                               shadow =True,colors=colors,labels =labels,fontsize = 12,startangle =70)
ax[0].set_ylabel("% of condition of loans,fontsize = 16")

palette = ["#3791D7","#E01E1B"]
sns.barplot(x="year",y="loan_amount",hue = 'loan_condition',data=data,palette = palette,estimator =lambda x: len(x)/len(data)*100)
ax[1].set(ylabel = "(%)")
# Out:
# [Text(0, 0.5, '(%)')]

# %%
# loans issued by region

# %%
data.addr_state.unique()
# Out:
# array(['AZ', 'GA', 'IL', 'CA', 'OR', 'NC', 'TX', 'VA', 'MO', 'CT', 'UT',
#        'FL', 'NY', 'PA', 'MN', 'NJ', 'KY', 'OH', 'SC', 'RI', 'LA', 'MA',
#        'WA', 'WI', 'AL', 'CO', 'KS', 'NV', 'AK', 'MD', 'WV', 'VT', 'MI',
#        'DC', 'SD', 'NH', 'AR', 'NM', 'MT', 'HI', 'WY', 'OK', 'DE', 'MS',
#        'TN', 'IA', 'NE', 'ID', 'IN', 'ME'], dtype=object)

# %%
west = ["CA","OR","UT","WA","CO","NV","AK","MT","HI","WY","ID"]
south_west = ['AZ', 'TX', 'NM', 'OK']
south_east = ['GA', 'NC', 'VA', 'FL', 'KY', 'SC', 'LA', 'AL', 'WV', 'DC', 'AR', 'DE', 'MS', 'TN' ]
mid_west = ['IL', 'MO', 'MN', 'OH', 'WI', 'KS', 'MI', 'SD', 'IA', 'NE', 'IN', 'ND']
north_east = ['CT', 'NY', 'PA', 'NJ', 'RI','MA', 'MD', 'VT', 'NH', 'ME']

data["region"]=np.nan

def finding_region(state):
    if state in west:
        return 'west'
    elif state in south_west:
        return 'south_west'
    elif state in south_east:
        return 'south_east'
    elif state in mid_west:
        return 'mid_west'
    elif state in north_east:
        return 'north_east'
data["region"]= data["addr_state"].apply(finding_region)

# %%
data.region
# Out:
# 0        south_west
# 1        south_east
# 2          mid_west
# 3              west
# 4              west
#             ...
# 39712          west
# 39713    south_east
# 39714    north_east
# 39715    north_east
# 39716    north_east
# Name: region, Length: 39717, dtype: object

# %%
data["complete_date"]= pd.to_datetime(data.issue_d.str.upper(),format = "%b-%y",yearfirst = False)
group_dates = data.groupby(["complete_date","region"],as_index = False).sum()

group_dates["issue_d"] = [month.to_period('M') for month in group_dates["complete_date"]]

group_dates =group_dates.groupby(['issue_d','region'],as_index = False).sum()
group_dates['loan_amount']=group_dates["loan_amount"]/1000

data_dates = pd.DataFrame(data = group_dates[["issue_d",'region','loan_amount']])

# %%
plt.style.use('dark_background')
cmap = plt.cm.Set3
issued_amount = data_dates.groupby(["issue_d",'region']).loan_amount.sum()
issued_amount.unstack().plot(stacked =False,colormap=cmap,grid =False,legend =True,figsize = (15,8))
plt.title("loan status by region", fontsize  = 16)
# Out:
# Text(0.5, 1.0, 'loan status by region')

# %%
data.emp_length.value_counts()
# Out:
# 10+ years    8879
# < 1 year     4583
# 2 years      4388
# 3 years      4095
# 4 years      3436
# 5 years      3282
# 1 year       3240
# 6 years      2229
# 7 years      1773
# 8 years      1479
# 9 years      1258
# Name: emp_length, dtype: int64

# %%
employee_length=['10+ years','<1 year','2 year','3 years','4 years','5 years','6 years','7 years','8 years','9 years','n/a']
lst=[data]
data["emp_length_int"]=np.nan

# %%
for col in lst:
    col.loc[col["emp_length"]=='10+ years',"emp_length_int"]=10
    col.loc[col["emp_length"]=='9 years',"emp_length_int"]=9
    col.loc[col["emp_length"]=='8 years',"emp_length_int"]=8
    col.loc[col["emp_length"]=='7 years',"emp_length_int"]=7
    col.loc[col["emp_length"]=='6 years',"emp_length_int"]=6
    col.loc[col["emp_length"]=='5 years',"emp_length_int"]=5
    col.loc[col["emp_length"]=='4 years',"emp_length_int"]=4
    col.loc[col["emp_length"]=='3 years',"emp_length_int"]=3
    col.loc[col["emp_length"]=='2 years',"emp_length_int"]=2
    col.loc[col["emp_length"]=='1 years',"emp_length_int"]=1
    col.loc[col["emp_length"]=='< 1 year',"emp_length_int"]=0.6
    col.loc[col["emp_length"]=='nan',"emp_length_int"]=0

# %%
data["intrest_rate"]=pd.to_numeric(data["intrest_rate"].apply(lambda x:x.split('%')[0]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-83-1d69be296e1f> in <module>
# ----> 1 data["intrest_rate"]=pd.to_numeric(data["intrest_rate"].apply(lambda x:x.split('%')[0]))
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-83-1d69be296e1f> in <lambda>(x)
# ----> 1 data["intrest_rate"]=pd.to_numeric(data["intrest_rate"].apply(lambda x:x.split('%')[0]))
#
# AttributeError: 'float' object has no attribute 'split'

# %%
sns.set_style('whitegrid')

f, ((ax1,ax2),(ax3,ax4))=plt.subplots(2,2)
cmap = plt.cm.inferno

by_intrest_rate = data.groupby(['year','region']).intrest_rate.mean()
by_intrest_rate.unstack().plot(kind = "area",stacked = True,colormap =cmap,grid = False,legend = False,ax =ax1,figsize =(16,12))
ax1.set_title("Average intrest rate by region",fontsize=14)

by_employment_length = data.groupby(['year','region']).emp_length_int.mean()
by_employment_length.unstack().plot(kind = "area",stacked = True,colormap =cmap,grid = False,legend = False,ax =ax2,figsize =(16,12))
ax2.set_title("Average Employment length by region",fontsize=14)

by_dti = data.groupby(['year','region']).dti.mean()
by_dti.unstack().plot(kind = "area",stacked = True,colormap =cmap,grid = False,legend = False,ax =ax3,figsize =(16,12))
ax3.set_title("Average Debt to income by region",fontsize=14)

by_income = data.groupby(['year','region']).annual_income.mean()
by_income.unstack().plot(kind = "area",stacked = True,colormap =cmap,grid = False,legend = False,ax =ax4,figsize =(16,12))
ax4.set_title("Average Annual income by region",fontsize=14)
ax4.legend(bbox_to_anchor=(-1.0,-0.5,1.8,0.1),loc = 10,prop ={'size':12},ncol= 5,mode ="expnad",borderaxespad =0.)

# %%
badloans_data = data.loc[data["loan_condition"]=='Bad Loan']
loan_status_cross = pd.crosstab(badloans_data["region"],badloans_data["loan_status"]).apply(lambda x: x/x.sum()*100)
number_of_loanstatus = pd.crosstab(badloans_data["region"],badloans_data["loan_status"])
loan_status_cross["Charged Off"]= loan_status_cross["Charged Off"].apply(lambda x: round(x,2))
number_of_loanstatus["Total"] = number_of_loanstatus.sum(axis = 1)
number_of_loanstatus
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Charged Off'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-85-7960342e6bda> in <module>
# ...

# %%
data["income_category"]=np.nan

lst =[data]

for col in lst:
    col.loc[col["annual_income"]<=100000,'income_category']='Low'
    col.loc[(col["annual_income"]>100000) & (col["annual_income"]<=200000),'income_category']='Medium'
    col.loc[col["annual_income"]>200000,'income_category']='High'

# %%
# transform this loan_conditions to integer
lst = [data]
data["loan_condition_int"]=np.nan

for col in lst:
    col.loc[data["loan_condition"]=='Good_Loan','loan_condition_int']=0
    col.loc[data["loan_condition"]=='Bad_Loan','loan_condition_int']=1
    
data["loan_condition_int"]= data['loan_condition_int'].astype(int)

# %%
fig,((ax1,ax2),(ax3,ax4))=plt.subplots(nrows=2,ncols=2,figsize =(16,12))

sns.violinplot(x="income_category",y="loan_amount",data =data,palette= 'Set2',ax =ax1)
sns.violinplot(x="income_category",y="loan_condition_int",data =data,palette= 'Set2',ax =ax2)
sns.boxplot(x="income_category",y = 'emp_length_int',data=data,palette='Set2',ax=ax3)
sns.boxplot(x="income_category",y = 'intrest_rate',data=data,palette='Set2',ax=ax4)
# Out:
# <AxesSubplot:xlabel='income_category', ylabel='intrest_rate'>

# %%
plt.figure(figsize=(18,18))
bad_data = data.loc[data['loan_condition']=='Bad_Loan']
#plt.subplot(211)
g= sns.boxplot(x="home_ownership",y = "loan_amount",hue ="loan_condition",data=bad_data,color='r')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(style="whitegrid")
plt.style.use("ggplot")
plt.rcParams['figure.figsize']=(12,8)
pd.option.mode.chained_assignement=none
pd.option
